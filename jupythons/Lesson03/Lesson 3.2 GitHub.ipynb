# %% [markdown]
# ### 🤓 Git и GitHub
#
# **Git** — это распределённая система контроля версий (VCS), которая помогает следить за изменениями, пока вы работаете над новыми программами и проектами. Git позволяет отслеживать изменения, которые вы вносите, чтобы всегда иметь данные о том, над чем вы работали, и предоставляет лёгкую возможность вернуться к более старой версии вашей программы, если это необходимо. Он также упрощает совместную работу в команде. Люди могут работать над одним проектом в своих ветках и вносить изменения в финальную версию проекта.
#
# **GitHub** — это веб-платформа для совместной работы над проектами. Она позволяет хранить код и другие файлы, отслеживать изменения и управлять проектами в команде. GitHub используется как для закрытых, так и для открытых проектов и предоставляет мощные инструменты для контроля версий, основанные на Git.
#
# **GitHub** также является мощной системой контроля версий. Он использует Git, самую популярную на сегодняшний день систему контроля версий, для отслеживания каждого вклада и участника вашего проекта, чтобы вы знали, откуда появилась каждая строка кода!
#
# **GitHub** помогает людям делать больше. Он используется для разработки передовых технологий по всему миру. Если вы хотите отобразить данные или создать новую игру, на GitHub есть целое сообщество и набор инструментов, которые помогут вам сделать следующий шаг. Этот урок — лишь начало.

# %% [markdown]
# ## 💻 Особенности GitHub
#
# ### Репозитории
#
# Репозиторий — это место, где происходит работа над вашим проектом. Он содержит все файлы вашего проекта и историю изменений. Вы можете работать в репозитории самостоятельно или приглашать других для совместной работы над этими файлами. По мере увеличения числа проектов у вас может быть множество репозиториев. Используйте панель управления GitHub, чтобы легко переходить между ними. Однако для этого вы должны быть авторизованы в системе!
#
# Репозитории также содержат файлы README. Вы можете добавить файл README в свой репозиторий, чтобы рассказать другим, почему ваш проект полезен, что они могут делать с вашим проектом и как они могут его использовать. Мы используем этот README, чтобы сообщить вам, как изучать Git и GitHub. 😄
#
# Чтобы узнать больше о репозиториях, читайте ["Создание, клонирование и архивирование репозиториев"](https://docs.github.com/en/github/creating-cloning-and-archiving-repositories/about-repositories) и ["О файлах README"](https://docs.github.com/en/github/creating-cloning-and-archiving-repositories/about-readmes).

# %% [markdown]
# ### Pull Requests (Запросы на вытягивание)
#
# Запросы на вытягивание (pull requests) позволяют вам сообщать другим об изменениях, которые вы отправили в ветку репозитория на GitHub. После открытия запроса на вытягивание, вы можете обсудить и просмотреть потенциальные изменения с соавторами и при необходимости добавить другие изменения.
#
# Добавление кого-либо в качестве рецензента в ваш pull request сигнализирует им, что вам нужна помощь или вы хотите, чтобы они просмотрели контент.
#
# Процесс создания pull request включает в себя несколько шагов:
# 1. **Форк** (fork) - создание личной копии проекта в вашем аккаунте.
# 2. **Внесение изменений** - изменение файлов в форкнутом репозитории.
# 3. **Создание Pull Request** - отправка запроса на слияние ваших изменений в оригинальный проект.
#
# Чтобы узнать больше о pull requests, читайте ["О запросах на вытягивание"](https://docs.github.com/en/github/collaborating-with-issues-and-pull-requests/about-pull-requests).

# %% [markdown]
# ### Issues (Проблемы)
#
# Issues на GitHub используются для отслеживания улучшений, задач или ошибок в вашем проекте. Это отличный способ управлять задачами, которые вы хотите выполнить или обсудить. Для более крупных проектов вы можете отслеживать множество проблем на доске проекта, которая помогает организовать работу и расставить приоритеты.
#
# Связывание запросов на вытягивание и проблем позволяет автоматически закрывать проблему, когда кто-то объединяет запрос на вытягивание. Это полезно для управления задачами и отслеживания прогресса в проекте.
#
# Чтобы узнать больше о проблемах и как их связывать с вашими pull requests, читайте ["О проблемах"](https://docs.github.com/en/github/managing-your-work-on-github/about-issues).

# %% [markdown]
# ### Ваш профиль пользователя
#
# Страница вашего профиля на GitHub рассказывает людям историю вашей работы через репозитории, которые вас интересуют, ваши вклады и общение, в котором вы участвовали. Вы также можете дать миру уникальное представление о себе, используя файл README вашего профиля. Это отличный способ показать будущим работодателям или соавторам, кто вы и чем занимаетесь.
#
# Настройка вашего профиля на GitHub помогает вам выделиться и может включать в себя как профессиональные, так и личные элементы, такие как:
# - Ваши текущие проекты и интересы.
# - Контактная информация.
# - Ссылки на ваши социальные сети или личный сайт.
#
# Чтобы узнать больше о вашем профиле пользователя и как добавлять и обновлять файл README профиля, читайте ["Управление README вашего профиля"](https://docs.github.com/en/github/setting-up-and-managing-your-github-profile/managing-your-profile-readme).

# %% [markdown]
# ### Использование Markdown на GitHub
#
# На GitHub можно использовать Markdown для минимального стилизирования ваших задач, запросов на вытягивание и файлов (если они имеют формат .md). Markdown помогает организовать вашу информацию и упростить её чтение для других пользователей. Вы также можете добавить гифки и изображения, чтобы выразить свою точку зрения более наглядно.
#
# Некоторые из возможностей Markdown включают:
# - Заголовки и подзаголовки (#, ##, ### и т.д.).
# - Списки (нумерованные и ненумерованные).
# - Ссылки и изображения.
# - Форматирование текста (жирный, курсив).
# - Встраивание кода и цитат.
#
# Markdown — это простой язык разметки, который легко изучить и применять. Он широко используется в файлах README, issues и комментариях.
#
# Чтобы узнать больше о синтаксисе Markdown на GitHub, читайте ["Основной синтаксис написания и форматирования"](https://docs.github.com/en/github/writing-on-github/basic-writing-and-formatting-syntax).

# %% [markdown]
# ### Взаимодействие с сообществом GitHub
#
# Сообщество GitHub огромно и разнообразно. Оно включает студентов, профессиональных разработчиков, любителей и исследователей, которые используют GitHub для своих проектов. Взаимодействие с сообществом может помочь вам развивать свои навыки, находить интересные проекты и сотрудничать с другими пользователями.
#
# #### Помеченные звёздочками репозитории
#
# Если вы находите репозиторий интересным или хотите отслеживать его обновления, пометьте его звёздочкой! Это также помогает GitHub давать вам более точные рекомендации в разделе "GitHub Explore".
#
# #### Подписка на пользователей
#
# Вы можете подписаться на других пользователей GitHub, чтобы получать уведомления об их активности и находить проекты, над которыми они работают. Это отличный способ следить за интересными разработчиками и их вкладом в сообщество.
#
# #### Обзор GitHub Explore
#
# GitHub Explore — это место, где можно найти новые проекты, события и разработчиков для взаимодействия. Чем больше вы взаимодействуете с GitHub, тем более персонализированным становится ваш опыт просмотра.
#
# Чтобы узнать больше о взаимодействии с сообществом GitHub, изучите [GitHub Explore](https://github.com/explore).

# %% [markdown]
# ## 🤓 Понимание GitHub Flow
#
# GitHub Flow — это простой и эффективный рабочий процесс, который позволяет безопасно экспериментировать с новыми идеями, не опасаясь компрометации проекта. Он подходит как для индивидуальных, так и для командных проектов и включает в себя несколько ключевых этапов.
#
# ### Ветвление (Branching)
#
# Ветвление позволяет изолировать работу, которую вы не хотите сразу объединять в основной проект. Ветки позволяют разрабатывать функции, исправлять ошибки или экспериментировать с новыми идеями в изолированной области вашего репозитория. Обычно вы создаете новую ветку из основной ветки вашего репозитория, которая по умолчанию называется `main`.
#
# После завершения работы в ветке и проверки изменений вы можете объединить её с основной веткой, сделав ваши изменения частью финальной версии проекта.
#
# Чтобы узнать больше о ветвлении, читайте ["О ветках"](https://docs.github.com/en/github/collaborating-with-issues-and-pull-requests/about-branches).

# %% [markdown]
# ### Клонирование и форк
#
# #### Клонирование
#
# Когда вы создаете репозиторий на GitHub, он существует удаленно, за пределами вашего локального компьютера. Вы можете клонировать репозиторий, чтобы создать его локальную копию на вашем компьютере и использовать Git для синхронизации изменений между локальной и удаленной версиями.
#
# Клонирование полезно для внесения изменений, добавления или удаления файлов, а также для работы с более крупными коммитами. Это позволяет вам использовать вашу любимую среду разработки или редактор кода вместо веб-интерфейса GitHub.
#
# Чтобы узнать больше о клонировании, читайте ["Клонирование репозитория"](https://docs.github.com/en/github/creating-cloning-and-archiving-repositories/cloning-a-repository).
#
# #### Форк
#
# Форк — это еще один способ скопировать репозиторий, который чаще всего используется при участии в чужих проектах. Форк позволяет вам свободно экспериментировать с изменениями, не затрагивая исходный проект. Это особенно полезно для участия в проектах с открытым исходным кодом.
#
# Чтобы узнать больше о форке, читайте ["Форк репозитория"](https://docs.github.com/en/github/getting-started-with-github/fork-a-repo).

# %% [markdown]
# ## Выдача и объяснение Homework
#
# В этой части мы обсудим, как сдавать домашние задания с использованием GitHub, а также предоставим ссылки на файлы .py с заданиями и test.py для проверки.
#
# ### Структура домашних заданий
#
# 1. **Ссылки на файлы .py**: Каждый студент получит ссылки на файлы с заданиями, которые необходимо выполнить. Файлы будут содержать функции, которые нужно реализовать или изменить.
#
# 2. **Алгоритм тестирования**: В файлах test.py будут находиться тесты, которые помогут проверить корректность выполнения заданий. Эти тесты можно запускать локально, чтобы убедиться, что ваше решение работает правильно.
#
# ### Использование GitHub для сдачи домашних заданий
#
# 1. **Создание репозитория**: Каждый студент должен создать свой репозиторий на GitHub, куда будут загружены выполненные задания.
#
# 2. **Команды для коммита**: Используйте команды `git add`, `git commit` и `git push`, чтобы отправить изменения в ваш репозиторий на GitHub.
#
# 3. **Предоставление доступа**: Убедитесь, что у вашего преподавателя есть доступ к вашему репозиторию, чтобы он мог проверить выполненные задания.
