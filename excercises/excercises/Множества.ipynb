# %% [markdown]
# ## Сборник задач по теме Множества

# %% [markdown]
# * Создайте множество, в качестве элементов которого используйте целое, вещественное и комплексное числа, а также строки в формате кортежа, списка и словаря, содержащих по одному элементу. Выведите полученное множество на экран.

# %%
#Напишите ваше решение здесь

# %% [markdown]
# * Дано множество {'a', 'b', 'c'}. Удалите из него строку 'c', а затем добавьте элемент 'd'. Выведите итоговое множество на экран.

# %%
#Напишите ваше решение здесь

# %% [markdown]
# * Даны множества {'a', 'b'} и {'b', 'c'}. Множества простые, поэтому сперва назовите результат их объединения, пересечения, разности и симметричной разницы устно, а затем проверьте себя, выведя результаты на экран.

# %%
#Напишите ваше решение здесь

# %% [markdown]
# * Решите предыдущую задачу, использовав для получения результатов соответствующие методы класса set.

# %%
#Напишите ваше решение здесь

# %% [markdown]
# * Дано множество целых чисел {-3, 8, 15, -5, 0, 7}. Выведите на экран произведение максимального и минимального элементов, сумму элементов не превышающих 7.

# %%
#Напишите ваше решение здесь

# %% [markdown]
# * Определите есть ли в строке 'Купить, нельзя оставить!' хотя бы одна точка или запятая.Выведите результат проверки на экран.

# %%
#Напишите ваше решение здесь

# %% [markdown]
# * Даны три слова 'аквариум', 'мармелад' и 'рама'. Выведите на экран сперва все виды букв, которые присутствуют во всех словах сразу, а затем все виды букв, которые присутствуют в любом из них.

# %%
#Напишите ваше решение здесь

# %% [markdown]
# * Даны три числа: 30, 5 и 25. Выведите на экран наименьшее из них, использовав для этого программную проверку.

# %%
#Напишите ваше решение здесь

# %% [markdown]
# * Даны два списка ников ['ivan2022', 'sveta', 'ivan', 'kot23', 'sveta', 'ivan'] и ['koly', 'enot37', 'luzer', 'kot23', 'sveta']. Сколько уникальных ников представлено в обоих списках? В каком списке уникальных ников содержится больше? Выведите результаты на экран.

# %%
#Напишите ваше решение здесь

# %% [markdown]
# * Сформируйте и выведите на экран множество из всех подходящих для этого элементов списка [True, 0, 1, False, 2+3.4j, 5, '5', (6, 7), [8, 9], {'10': 10}]. Объясните конечный результат. Используйте для решения задачи генератор множеств и класс Hashable модуля collections.abc для проверки хешируемости элементов списка.

# %%
#Напишите ваше решение здесь

# %% [markdown]
# Write a Python program to create a set.

# %%
#Напишите ваше решение здесь

# %% [markdown]
# Write a Python program to iterate over sets.

# %%
#Напишите ваше решение здесь

# %% [markdown]
# Write a Python program to add member(s) to a set.

# %%
#Напишите ваше решение здесь

# %% [markdown]
# Write a Python program to remove item(s) from a given set.

# %%
#Напишите ваше решение здесь

# %% [markdown]
# Write a Python program to remove an item from a set if it is present in the set.

# %%
#Напишите ваше решение здесь

# %% [markdown]
# Write a Python program to create an intersection of sets.

# %%
#Напишите ваше решение здесь

# %% [markdown]
# Write a Python program to create a union of sets.

# %%
#Напишите ваше решение здесь

# %% [markdown]
# Write a Python program to create set difference.

# %%
#Напишите ваше решение здесь

# %% [markdown]
# Write a Python program to create a symmetric difference.

# %%
#Напишите ваше решение здесь

# %% [markdown]
# Write a Python program to check if a set is a subset of another set.

# %%
#Напишите ваше решение здесь

# %% [markdown]
# Write a Python program to create a shallow copy of sets.

# %%
#Напишите ваше решение здесь

# %% [markdown]
# Write a Python program to remove all elements from a given set.

# %%
#Напишите ваше решение здесь

# %% [markdown]
# Write a Python program that uses frozensets.
# Note: Frozensets behave just like sets except they are immutable.

# %%
#Напишите ваше решение здесь

# %% [markdown]
# Write a Python program to find the maximum and minimum values in a set.

# %%
#Напишите ваше решение здесь

# %% [markdown]
# Write a Python program to find the length of a set.

# %%
#Напишите ваше решение здесь

# %% [markdown]
# Write a Python program to check if a given value is present in a set or not.

# %%
#Напишите ваше решение здесь

# %% [markdown]
# Write a Python program to check if two given sets have no elements in common.

# %%
#Напишите ваше решение здесь

# %% [markdown]
# Write a Python program to check if a given set is a superset of itself and a superset of another given set.

# %%
#Напишите ваше решение здесь

# %% [markdown]
# Write a Python program to find elements in a given set that are not in another set.

# %%
#Напишите ваше решение здесь

# %% [markdown]
# Write a Python program to remove the intersection of a second set with a first set.

# %%
#Напишите ваше решение здесь

# %% [markdown]
# Write a Python program to find all the unique words and count the frequency of occurrence from a given list of strings. Use Python set data type.

# %%
#Напишите ваше решение здесь

# %% [markdown]
# Write a Python program that finds all pairs of elements in a list whose sum is equal to a given value.

# %%
#Напишите ваше решение здесь

# %% [markdown]
# Write a Python program to find the longest common prefix of all strings. Use the Python set.

# %%
#Напишите ваше решение здесь

# %% [markdown]
# Write a Python program to find the two numbers whose product is maximum among all the pairs in a given list of numbers. Use the Python set.

# %%
#Напишите ваше решение здесь

# %% [markdown]
# Given two sets of numbers, write a Python program to find the missing numbers in the second set as compared to the first and vice versa. Use the Python set.

# %%
#Напишите ваше решение здесь

# %% [markdown]
# Write a Python program to find all the anagrams and group them together from a given list of strings. Use the Python data type.

# %%
#Напишите ваше решение здесь

# %% [markdown]
# Write a Python program to find all the anagrams in a given list of strings and then group them together. Use the Python data type.

# %%
#Напишите ваше решение здесь

# %% [markdown]
# Write a Python program to find all the unique combinations of 3 numbers from a given list of numbers, adding up to a target number.

# %%
#Напишите ваше решение здесь

# %% [markdown]
# Write a Python program to find the third largest number from a given list of numbers.Use the Python set data type.

# %%
#Напишите ваше решение здесь

# %% [markdown]
# Write a Python program to remove all duplicates from a given list of strings and return a list of unique strings. Use the Python set data type.

# %%
#Напишите ваше решение здесь
